# %%
# importing useful libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install seaborn 
# !pip install pyarrow 
# !pip install fastparquet
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
train = pd.read_parquet('train_data.parquet')
test = pd.read_parquet('test_data.parquet')
transactions = pd.read_parquet('add_trans.parquet')
events = pd.read_parquet('add_event.parquet')
offer_metadata = pd.read_parquet('offer_metadata.parquet')

# %%
headings=pd.read_csv('data_dictionary.csv')
pd.set_option('display.max_rows', 376)
headings
# Out:
#     masked_column                                        Description  \
# 0             id1                                Primary Key(masked)
# 1             id2                               Customer ID (masked)
# 2             id3                                           Offer ID
# 3             id4                                    Event timestamp
# 4             id5                                         Event Date
# 5               y                                 Dependent Variable
# 6              f1   Interest score of a customer with intrst_id =...
# 7              f2   Interest score of a customer with intrst_id =...
# 8              f3   Interest score of a customer with intrst_id =...
# 9              f4   Interest score of a customer with intrst_id =...
# 10             f5   Interest score of a customer with intrst_id =...
# 11             f6   Interest score of a customer with intrst_id =...
# 12             f7   Interest score of a customer with intrst_id =...
# ...
